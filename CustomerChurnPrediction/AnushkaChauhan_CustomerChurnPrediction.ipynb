# %% [markdown]
# # RetentionPulse — Customer Churn Prediction
#
# Public Kaggle Telco Customer Churn analysis and Logistic Regression modelling.

# %%
import pandas as pd
from pathlib import Path
from src.churn_pipeline import run
result = run()
result['summary']
